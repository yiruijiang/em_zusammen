# %% [markdown]
# # 💰 Introduction to IBKR

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import nest_asyncio
import pandas as pd

nest_asyncio.apply()
import sys
import os

# Add project root (adjust '..' as needed)
sys.path.append(os.path.abspath(".."))

from em.source import tools

# %%
df = tools.retrieve_historical_stock_data(
    stock='AAPL',
    currency='USD',
    duration='5 Y'
)
plt.figure(figsize=(12, 6))
ax = plt.gca()
df.plot(x='date', y='close', title='AAPL 5-Year Close Price', ax=ax)
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %%
df.head(100)
# Out:
#           date    open    high     low   close       volume    average  \
# 0   2020-05-18   77.47   79.13   77.12   78.92  112114924.0   78.52275
# 1   2020-05-19   79.00   79.63   78.17   78.64   84924048.0   79.09200
# 2   2020-05-20   78.76   79.90   78.29   79.79   94027904.0   79.62275
# 3   2020-05-21   79.53   80.22   78.97   79.50   83482136.0   79.53825
# 4   2020-05-22   78.35   79.81   78.13   79.77   67948360.0   79.38925
# ..         ...     ...     ...     ...     ...          ...        ...
# 95  2020-10-01  116.71  118.10  115.83  116.80  105372650.0  116.59100
# 96  2020-10-02  114.65  117.08  112.22  112.58  129286278.0  113.87800
# 97  2020-10-05  113.75  116.66  113.30  115.76   94002566.0  115.43400
# 98  2020-10-06  115.76  116.79  112.25  113.20  143282905.0  114.45000
# 99  2020-10-07  114.10  115.55  113.13  115.37   88140933.0  114.92300
#
#     barCount
# 0     123937
# 1     100487
# 2     110252
# 3      98102
# 4      83651
# ..       ...
# ...
